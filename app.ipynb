# %%
from pizza import *

# %%
location = '40.6915812,-73.9954095'
keyword = 'pizza'
ltype = 'establishment'
rankby = 'distance'

print("Searching Google Maps")
gmaps_df = gmaps_get_df(location, keyword)
print("%d results" % len(gmaps_df))

print("Searching Yelp")
yelp_df = yelp_get_df(location, keyword)
print("%d results" % len(yelp_df))

print("Searching Foursquare")
foursquare_df = foursquare_get_df(location, keyword)
print("%d results" % len(foursquare_df))

print("Running dedupe")
dedupe_list = list(filter(lambda df: df is not None, [gmaps_df, yelp_df, foursquare_df]))
print(len(gmaps_df), len(yelp_df), len(foursquare_df))
print("Deduping %d dataframes" % (len(list(dedupe_list))))
dedupe(dedupe_list)
# Out:
# Searching on Google Maps
# 57 results
# Searching on Yelp
# 36 results
# Searching on foursquare
# <class 'KeyError'> 'rating'
# Traceback (most recent call last):
#   File "/Users/drucev/projects/maps/Pizza/Pizza/pizza.py", line 156, in foursquare_get_df
#     venue_rating = venue_details['rating']
# KeyError: 'rating'
#
# No rating for Jay St. Fresh 99¢ Pizza
# <class 'KeyError'> 'rating'
# Traceback (most recent call last):
#   File "/Users/drucev/projects/maps/Pizza/Pizza/pizza.py", line 156, in foursquare_get_df
#     venue_rating = venue_details['rating']
# KeyError: 'rating'
#
# No rating for Mario's Pizza & Chicken
# <class 'KeyError'> 'rating'
# Traceback (most recent call last):
#   File "/Users/drucev/projects/maps/Pizza/Pizza/pizza.py", line 156, in foursquare_get_df
#     venue_rating = venue_details['rating']
# KeyError: 'rating'
#
# No rating for 99 Cent Pizza
# <class 'KeyError'> 'rating'
# Traceback (most recent call last):
#   File "/Users/drucev/projects/maps/Pizza/Pizza/pizza.py", line 156, in foursquare_get_df
#     venue_rating = venue_details['rating']
# KeyError: 'rating'
#
# No rating for Texas Fried Chicken & Pizza
# <class 'KeyError'> 'rating'
# Traceback (most recent call last):
#   File "/Users/drucev/projects/maps/Pizza/Pizza/pizza.py", line 156, in foursquare_get_df
#     venue_rating = venue_details['rating']
# KeyError: 'rating'
#
# No rating for S&S Brooklyn Pizza
# <class 'KeyError'> 'rating'
# Traceback (most recent call last):
#   File "/Users/drucev/projects/maps/Pizza/Pizza/pizza.py", line 156, in foursquare_get_df
#     venue_rating = venue_details['rating']
# KeyError: 'rating'
#
# No rating for Pizza Rustica
# <class 'KeyError'> 'rating'
# Traceback (most recent call last):
#   File "/Users/drucev/projects/maps/Pizza/Pizza/pizza.py", line 156, in foursquare_get_df
#     venue_rating = venue_details['rating']
# KeyError: 'rating'
#
# No rating for Torpedo Pizza
# <class 'KeyError'> 'rating'
# Traceback (most recent call last):
#   File "/Users/drucev/projects/maps/Pizza/Pizza/pizza.py", line 156, in foursquare_get_df
#     venue_rating = venue_details['rating']
# KeyError: 'rating'
#
# No rating for Pizza Cafe
# <class 'KeyError'> 'rating'
# Traceback (most recent call last):
#   File "/Users/drucev/projects/maps/Pizza/Pizza/pizza.py", line 156, in foursquare_get_df
#     venue_rating = venue_details['rating']
# KeyError: 'rating'
#
# No rating for Primo New York Pizza
# <class 'KeyError'> 'rating'
# Traceback (most recent call last):
#   File "/Users/drucev/projects/maps/Pizza/Pizza/pizza.py", line 156, in foursquare_get_df
#     venue_rating = venue_details['rating']
# KeyError: 'rating'
#
# No rating for Pizza Moto
# <class 'KeyError'> 'rating'
# Traceback (most recent call last):
#   File "/Users/drucev/projects/maps/Pizza/Pizza/pizza.py", line 156, in foursquare_get_df
#     venue_rating = venue_details['rating']
# KeyError: 'rating'
#
# No rating for pizza vn
# 50 results
# Running dedupe
# 57 36 50
# Deduping 3 dataframes
# > /Users/drucev/projects/maps/Pizza/Pizza/pizza.py(178)dedupe()
# -> for i, source_df in enumerate(dedupe_list):
# (Pdb) c
# Importing data ...
# Reading from dedupe_dataframe_learned_settings
# Clustering...
# # duplicate sets 99
#     cluster                  name           address         lat          lng  \
# 0         0             Juliana's  19 Old Fulton St  40.7027467  -73.9934349
# 1         1             Sottocasa  298 Atlantic Ave  40.6883065  -73.9889778
# 4         4    Piz-zetta Pizzeria  90 Livingston St  40.6911691  -73.9906319
# 5         5                Lucali      575 Henry St  40.6818053  -74.0002926
# 35       35        Manero's Pizza   113 Mulberry St  40.7176209  -73.9984521
# ..      ...                   ...               ...         ...          ...
# 57       57     Papa John's Pizza   148 Lawrence St  40.6918197  -73.9864769
# 55       55          Love & Dough       57 Pearl St  40.7029363  -73.9874841
# 58       58  South Brooklyn Pizza        63 4th Ave    40.68217   -73.979435
# 31       31              Caruso's      150 Smith St  40.6866275  -73.9908217
# 32       32      Mario's Pizzeria       222 Hoyt St  40.6835743  -73.9899575
#
#    source gmaps_rating  gmaps_rating_std yelp_rating  yelp_rating_std  \
# 0       0          4.6          1.259980         4.5         1.535002
# 1       0          4.6          1.259980         4.5         1.535002
# 4       0          4.6          1.259980         4.5         1.535002
# 5       0          4.5          0.907926         4.5         1.535002
# 35      0          4.7          1.612033         NaN              NaN
# ..    ...          ...               ...         ...              ...
# 57      0          3.7         -1.908499         NaN              NaN
# 55      0          3.7         -1.908499         NaN              NaN
# 58      0          3.6         -2.260552         NaN              NaN
# 31      0          3.7         -1.908499         3.0        -1.848268
# 32      0          3.6         -2.260552         NaN              NaN
#
#    foursquare_rating  foursquare_rating_std  nratings         w         R  \
# 0                9.0               1.034734         3  0.675000  1.276572
# 1                NaN                    NaN         2  0.580645  1.397491
# 4                NaN                    NaN         2  0.580645  1.397491
# 5                NaN                    NaN         2  0.580645  1.221464
# 35               NaN                    NaN         1  0.409091  1.612033
# ..               ...                    ...       ...       ...       ...
# 57               NaN                    NaN         1  0.409091 -1.908499
# 55               NaN                    NaN         1  0.409091 -1.908499
# 58               NaN                    NaN         1  0.409091 -2.260552
# 31               NaN                    NaN         2  0.580645 -1.878383
# 32              -1.0              -1.812635         2  0.580645 -2.036593
#
#     bayes_score
# 0      0.861686
# 1      0.811446
# 4      0.811446
# 5      0.709237
# 35     0.659468
# ..          ...
# 57    -0.780749
# 55    -0.780749
# 58    -0.924771
# 31    -1.090674
# 32    -1.182538
#
# [99 rows x 16 columns]
