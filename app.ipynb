# %%
from pizza import *

# %%
location = (40.6915812,-73.9954095)
keyword = 'pizza'
ltype = 'establishment'
rankby = 'distance'

print("Searching Google Maps")
gmaps_df = gmaps_get_df(location, keyword)
print("%d results" % len(gmaps_df))

print("Searching Yelp")
yelp_df = yelp_get_df(location, keyword)
print("%d results" % len(yelp_df))

print("Searching Foursquare")
foursquare_df = foursquare_get_df(location, keyword)
print("%d results" % len(foursquare_df))

print("Running dedupe")
dedupe_list = list(filter(lambda df: df is not None, [gmaps_df, yelp_df, foursquare_df]))
print(len(gmaps_df), len(yelp_df), len(foursquare_df))
print("Deduping %d dataframes" % (len(list(dedupe_list))))
dedupe(dedupe_list)
# Out:
# Searching Google Maps
# 27 results
# Searching Yelp
# 31 results
# Searching Foursquare
# 14 results
# Running dedupe
# 27 31 14
# Deduping 3 dataframes
# Importing data ...
# Reading from dedupe_dataframe_learned_settings
# Clustering...
# # duplicate sets 40
#     cluster                                         name  \
# 5         5                                       Lucali
# 0         0                                    Juliana's
# 1         1                                    Sottocasa
# 4         4                           Piz-zetta Pizzeria
# 2         2                                 Dellarocco's
# 7         7                                      Luzzo's
# 8         8                                        Brado
# 6         6                                     Table 87
# 24       24                         Forcella Fried Pizza
# 21       21                        Fatoosh Pitza & Grill
# 3         3                 The House of Pizza & Calzone
# 9         9                           Front Street Pizza
# 12       12                                    Numero 28
# 35       35                                   Claudine's
# 34       34                                        Sam's
# 33       33                                      Fornino
# 32       32                                  La Cigogne
# 20       20                                  Layla Jones
# 14       14                             Fascati Pizzeria
# 10       10                           My Little Pizzeria
# 25       25  Fornino At Pier 6-Open for the 2020 season!
# 26       26                         Fresh 99 cents pizza
# 19       19                             Enoteca on Court
# 22       22                        Brooklyn Pizza Market
# 17       17                                 Norm’s Pizza
# 27       27                                2 Bros. Pizza
# 28       28                        Brooklyn Pizza Market
# 37       37                                 Pronto Pizza
# 36       36                                    Ignazio's
# 13       13                          Grimaldi's Pizzeria
# 11       11                            Sal's Pizza Store
# 29       29                           99 Cents Hot Pizza
# 16       16             Francesco's Pizzeria & Trattoria
# 18       18                           Antonio's Pizzeria
# 39       39                                 Pronto Pizza
# 15       15                                    Monty Q's
# 38       38                                 Love & Dough
# 30       30                            Papa John's Pizza
# 31       31                             Mario's Pizzeria
# 23       23                Caruso Pizzeria &  Restaurant
#
#                                         address                 lat  \
# 5                                  575 Henry St          40.6818053
# 0                              19 Old Fulton St          40.7027467
# 1                              298 Atlantic Ave          40.6883065
# 4                              90 Livingston St          40.6911691
# 2                                  214 Hicks St          40.6950091
# 7                              145 Atlantic Ave           40.690696
# 8                              155 Atlantic Ave   40.69064520000001
# 6                               87 Atlantic Ave          40.6912825
# 24                           445 Albee Square W          40.6911058
# 21                                 330 Hicks St             40.6915
# 3                                  132 Union St          40.6839972
# 9                                   80 Front St          40.7023963
# 12                                 68 Bergen St          40.6867129
# 35                                 311 Smith St     40.681266784668
# 34                                 238 Court St     40.685920715332
# 33                  Pier 6 Brooklyn Bridge Park    40.6928735340776
# 32                                 215 Union St           40.683501
# 20                                 214 Court St            40.68669
# 14                                  80 Henry St          40.6985047
# 10                                 114 Court St          40.6902356
# 25  Brooklyn Bridge Park Pier 6  Bridge Park Dr          40.6931806
# 26                             51 Willoughby St          40.6923262
# 19                                 347 Court St    40.6821365356445
# 22                                 267 Smith St            40.68273
# 17                                 345 Adams St           40.692794
# 27                   395 Flatbush Ave Ext #5321          40.6894392
# 28                               267 A Smith St          40.6826629
# 37                                    139 Ct St            40.68946
# 36                                   4 Water St           40.703137
# 13                                   1 Front St           40.702583
# 11                                 305 Court St          40.6836079
# 29                            255 Livingston St   40.68882420000001
# 16                                 529 Henry St          40.6836026
# 18                                  32 Court St          40.6929516
# 39                                 139 Court St  40.689508537897716
# 15                              158 Montague St          40.6942108
# 38                                  57 Pearl St          40.7030253
# 30                              148 Lawrence St          40.6918197
# 31                                  222 Hoyt St          40.6835743
# 23                                 150 Smith St           40.686637
#
#                    lng             distance source gmaps_rating  \
# 5          -74.0002926   1.1614210082934948      0          4.5
# 0          -73.9934349   1.2510884703746683      0          4.6
# 1          -73.9889778   0.6540693037982467      0          4.6
# 4          -73.9906319   0.4064180424981932      0          4.6
# 2          -73.9961082  0.38521527537194344      0          4.6
# 7   -73.99522499999999  0.09952903372102893      0          4.5
# 8          -73.9949106  0.11216972425363314      0          4.5
# 6          -73.9973211  0.16495006034714688      0          4.5
# 24         -73.9831758   1.0354179159576993      0          4.5
# 21           -73.99777    0.199727742106794      1          NaN
# 3   -74.00228129999999    1.023083746411481      0          4.6
# 9          -73.9894556    1.302160081002831      0          4.4
# 12         -73.9909624   0.6584620784881503      0          4.3
# 35   -73.9939117431641   1.1523699836882666      1          NaN
# 34   -73.9945220947266    0.633044876131373      1          NaN
# 33   -74.0016932280972   0.5501808419597831      1          NaN
# 32          -73.999304   0.9557744597772352      1          NaN
# 20            -73.9941   0.5543217334067823      1          NaN
# 14         -73.9927592   0.8008096018547488      0          4.2
# 10          -73.992334   0.2998479748841386      0          4.4
# 25         -74.0011955   0.5203147354689558      0          4.3
# 26         -73.9868473   0.7284389670111076      0          4.3
# 19   -73.9957122802734    1.049122019317376      1          NaN
# 22           -73.99305   1.0029393150106678      1          NaN
# 17         -73.9886035   0.5908343301902241      0          4.0
# 27         -73.9809399   1.2459944341967508      0          4.1
# 28         -73.9930802   1.0097419861276682      0          4.1
# 37           -73.99233    0.351060443514373      1          NaN
# 36          -73.993608   1.2922506868350816      1          NaN
# 13          -73.993239   1.2354246533426436      0          4.2
# 11         -73.9951494   0.8856909573239773      0          4.4
# 29  -73.98328459999999    1.069643601127163      0          4.0
# 16  -73.99951159999999    0.951444658379107      0          4.1
# 18  -73.99100829999999  0.40193558806669877      0          3.9
# 39  -73.99249609938093   0.3370771353326898      2          NaN
# 15         -73.9929947   0.3562746812331634      0          4.1
# 38         -73.9874284   1.4387738914030213      1          NaN
# 30         -73.9864769   0.7555012870777589      0          3.7
# 31         -73.9899575   1.0014899339793415      0          3.6
# 23          -73.990783   0.6740828310871664      1          NaN
#
#     gmaps_rating_std yelp_rating  yelp_rating_std foursquare_rating  \
# 5           0.794834         4.5         1.569614               9.3
# 0           1.158571         4.5         1.569614               NaN
# 1           1.158571         4.5         1.569614               NaN
# 4           1.158571         4.5         1.569614               NaN
# 2           1.158571         4.0         0.411089               9.0
# 7           0.794834         4.0         0.411089               NaN
# 8           0.794834         4.0         0.411089               NaN
# 6           0.794834         4.0         0.411089               NaN
# 24          0.794834         NaN              NaN               NaN
# 21               NaN         4.0         0.411089               8.1
# 3           1.158571         4.0         0.411089               7.0
# 9           0.431096         4.0         0.411089               NaN
# 12          0.067359         4.0         0.411089               7.9
# 35               NaN         4.0         0.411089               NaN
# 34               NaN         4.0         0.411089               NaN
# 33               NaN         4.0         0.411089               NaN
# 32               NaN         4.0         0.411089               NaN
# 20               NaN         4.0         0.411089               7.3
# 14         -0.296379         4.0         0.411089               7.6
# 10          0.431096         3.5        -0.747435               7.9
# 25          0.067359         NaN              NaN               NaN
# 26          0.067359         NaN              NaN               NaN
# 19               NaN         4.0         0.411089               7.0
# 22               NaN         3.5        -0.747435               7.8
# 17         -1.023853         4.0         0.411089               NaN
# 27         -0.660116         NaN              NaN               NaN
# 28         -0.660116         NaN              NaN               NaN
# 37               NaN         3.5        -0.747435               NaN
# 36               NaN         3.5        -0.747435               NaN
# 13         -0.296379         3.5        -0.747435               NaN
# 11          0.431096         3.0        -1.905959               7.3
# 29         -1.023853         NaN              NaN               NaN
# 16         -0.660116         3.5        -0.747435               NaN
# 18         -1.387591         3.5        -0.747435               NaN
# 39               NaN         NaN              NaN               5.7
# 15         -0.660116         3.0        -1.905959               6.8
# 38               NaN         3.0        -1.905959               NaN
# 30         -2.115066         NaN              NaN               NaN
# 31         -2.478803         NaN              NaN               NaN
# 23               NaN         3.0        -1.905959               5.5
#
#     foursquare_rating_std  nratings         w         R  bayes_score
# 5                1.822689         3  0.625000  1.395712     0.872320
# 0                     NaN         2  0.526316  1.364092     0.717943
# 1                     NaN         2  0.526316  1.364092     0.717943
# 4                     NaN         2  0.526316  1.364092     0.717943
# 2                1.528254         3  0.625000  1.032638     0.645399
# 7                     NaN         2  0.526316  0.602961     0.317348
# 8                     NaN         2  0.526316  0.602961     0.317348
# 6                     NaN         2  0.526316  0.602961     0.317348
# 24                    NaN         1  0.357143  0.794834     0.283869
# 21               0.644951         2  0.526316  0.528020     0.277905
# 3               -0.434641         3  0.625000  0.378340     0.236462
# 9                     NaN         2  0.526316  0.421093     0.221628
# 12               0.448662         3  0.625000  0.309037     0.193148
# 35                    NaN         1  0.357143  0.411089     0.146818
# 34                    NaN         1  0.357143  0.411089     0.146818
# 33                    NaN         1  0.357143  0.411089     0.146818
# 32                    NaN         1  0.357143  0.411089     0.146818
# 20              -0.140207         2  0.526316  0.135441     0.071285
# 14               0.154227         3  0.625000  0.089646     0.056029
# 10               0.448662         3  0.625000  0.044108     0.027567
# 25                    NaN         1  0.357143  0.067359     0.024057
# 26                    NaN         1  0.357143  0.067359     0.024057
# 19              -0.434641         2  0.526316 -0.011776    -0.006198
# 22               0.350517         2  0.526316 -0.198459    -0.104452
# 17                    NaN         2  0.526316 -0.306382    -0.161254
# 27                    NaN         1  0.357143 -0.660116    -0.235756
# 28                    NaN         1  0.357143 -0.660116    -0.235756
# 37                    NaN         1  0.357143 -0.747435    -0.266941
# 36                    NaN         1  0.357143 -0.747435    -0.266941
# 13                    NaN         2  0.526316 -0.521907    -0.274688
# 11              -0.140207         3  0.625000 -0.538357    -0.336473
# 29                    NaN         1  0.357143 -1.023853    -0.365662
# 16                    NaN         2  0.526316 -0.703776    -0.370408
# 18                    NaN         2  0.526316 -1.067513    -0.561849
# 39              -1.710523         1  0.357143 -1.710523    -0.610901
# 15              -0.630931         3  0.625000 -1.065669    -0.666043
# 38                    NaN         1  0.357143 -1.905959    -0.680700
# 30                    NaN         1  0.357143 -2.115066    -0.755381
# 31                    NaN         1  0.357143 -2.478803    -0.885287
# 23              -1.906813         2  0.526316 -1.906386    -1.003361

# %%
dedupe_df = dedupe(dedupe_list)
dedupe_df
dedupe_df.to_pickle("pizza_brooklynheights.pkl")
# Out:
# Importing data ...
# Reading from dedupe_dataframe_learned_settings
# Clustering...
# # duplicate sets 40

# %%
dedupe_df = pd.read_pickle("pizza_brooklynheights.pkl")
tablecols = ['name', 'address', 'distance', 'gmaps_rating', 'yelp_rating', 'foursquare_rating']
tmpdf = dedupe_df.sort_values('bayes_score', ascending=False).reset_index(drop=True)[tablecols]
tmpdf['rank'] = tmpdf.index + 1
tmpdf['distance'] = tmpdf['distance'].apply(lambda d: "%1.1f km" % (float(d)))
tmpdf = tmpdf[['rank'] + tablecols]
tmpdf.columns=['Rank', 'Name', 'Address', 'Distance', 'Google Maps', 'Yelp', 'Foursquare']
retval = tmpdf.to_json(orient="records")
retval
# Out:
# '[{"Rank":1,"Name":"Lucali","Address":"575 Henry St","Distance":"1.2 km","Google Maps":"4.5","Yelp":"4.5","Foursquare":"9.3"},{"Rank":2,"Name":"Piz-zetta Pizzeria","Address":"90 Livingston St","Distance":"0.4 km","Google Maps":"4.6","Yelp":"4.5","Foursquare":null},{"Rank":3,"Name":"Juliana\'s","Address":"19 Old Fulton St","Distance":"1.3 km","Google Maps":"4.6","Yelp":"4.5","Foursquare":null},{"Rank":4,"Name":"Sottocasa","Address":"298 Atlantic Ave","Distance":"0.7 km","Google Maps":"4.6","Yelp":"4.5","Foursquare":null},{"Rank":5,"Name":"Dellarocco\'s","Address":"214 Hicks St","Distance":"0.4 km","Google Maps":"4.6","Yelp":"4.0","Foursquare":"9.0"},{"Rank":6,"Name":"Luzzo\'s","Address":"145 Atlantic Ave","Distance":"0.1 km","Google Maps":"4.5","Yelp":"4.0","Foursquare":null},{"Rank":7,"Name":"Brado","Address":"155 Atlantic Ave","Distance":"0.1 km","Google Maps":"4.5","Yelp":"4.0","Foursquare":null},{"Rank":8,"Name":"Table 87","Address":"87 Atlantic Ave","Distance":"0.2 km","Google Maps":"4.5","Yelp":"4.0","Foursquare":null},{"Rank":9,"Name":"Forcella Fried Pizza","Address":"445 Albee Square W","Distance":"1.0 km","Google Maps":"4.5","Yelp":null,"Foursquare":null},{"Rank":10,"Name":"Fatoosh Pitza & Grill","Address":"330 Hicks St","Distance":"0.2 km","Google Maps":null,"Yelp":"4.0","Foursquare":"8.1"},{"Rank":11,"Name":"The House of Pizza & Calzone","Address":"132 Union St","Distance":"1.0 km","Google Maps":"4.6","Yelp":"4.0","Foursquare":"7.0"},{"Rank":12,"Name":"Front Street Pizza","Address":"80 Front St","Distance":"1.3 km","Google Maps":"4.4","Yelp":"4.0","Foursquare":null},{"Rank":13,"Name":"Numero 28","Address":"68 Bergen St","Distance":"0.7 km","Google Maps":"4.3","Yelp":"4.0","Foursquare":"7.9"},{"Rank":14,"Name":"Claudine\'s","Address":"311 Smith St","Distance":"1.2 km","Google Maps":null,"Yelp":"4.0","Foursquare":null},{"Rank":15,"Name":"Sam\'s","Address":"238 Court St","Distance":"0.6 km","Google Maps":null,"Yelp":"4.0","Foursquare":null},{"Rank":16,"Name":"Fornino","Address":"Pier 6 Brooklyn Bridge Park","Distance":"0.6 km","Google Maps":null,"Yelp":"4.0","Foursquare":null},{"Rank":17,"Name":"La Cigogne ","Address":"215 Union St","Distance":"1.0 km","Google Maps":null,"Yelp":"4.0","Foursquare":null},{"Rank":18,"Name":"Layla Jones","Address":"214 Court St","Distance":"0.6 km","Google Maps":null,"Yelp":"4.0","Foursquare":"7.3"},{"Rank":19,"Name":"Fascati Pizzeria","Address":"80 Henry St","Distance":"0.8 km","Google Maps":"4.2","Yelp":"4.0","Foursquare":"7.6"},{"Rank":20,"Name":"My Little Pizzeria","Address":"114 Court St","Distance":"0.3 km","Google Maps":"4.4","Yelp":"3.5","Foursquare":"7.9"},{"Rank":21,"Name":"Fresh 99 cents pizza","Address":"51 Willoughby St","Distance":"0.7 km","Google Maps":"4.3","Yelp":null,"Foursquare":null},{"Rank":22,"Name":"Fornino At Pier 6-Open for the 2020 season!","Address":"Brooklyn Bridge Park Pier 6  Bridge Park Dr","Distance":"0.5 km","Google Maps":"4.3","Yelp":null,"Foursquare":null},{"Rank":23,"Name":"Enoteca on Court","Address":"347 Court St","Distance":"1.0 km","Google Maps":null,"Yelp":"4.0","Foursquare":"7.0"},{"Rank":24,"Name":"Brooklyn Pizza Market","Address":"267 Smith St","Distance":"1.0 km","Google Maps":null,"Yelp":"3.5","Foursquare":"7.8"},{"Rank":25,"Name":"Norm\\u2019s Pizza","Address":"345 Adams St","Distance":"0.6 km","Google Maps":"4.0","Yelp":"4.0","Foursquare":null},{"Rank":26,"Name":"2 Bros. Pizza","Address":"395 Flatbush Ave Ext #5321","Distance":"1.2 km","Google Maps":"4.1","Yelp":null,"Foursquare":null},{"Rank":27,"Name":"Brooklyn Pizza Market","Address":"267 A Smith St","Distance":"1.0 km","Google Maps":"4.1","Yelp":null,"Foursquare":null},{"Rank":28,"Name":"Pronto Pizza","Address":"139 Ct St","Distance":"0.4 km","Google Maps":null,"Yelp":"3.5","Foursquare":null},{"Rank":29,"Name":"Ignazio\'s","Address":"4 Water St","Distance":"1.3 km","Google Maps":null,"Yelp":"3.5","Foursquare":null},{"Rank":30,"Name":"Grimaldi\'s Pizzeria","Address":"1 Front St","Distance": ...

# %%
tmpdf['Distance'].apply(lambda d: "%1.1f km" % (float(d)))
# Out:
# 0     1.2 km
# 1     0.4 km
# 2     1.3 km
# 3     0.7 km
# 4     0.4 km
# 5     0.1 km
# 6     0.1 km
# 7     0.2 km
# 8     1.0 km
# 9     0.2 km
# 10    1.0 km
# 11    1.3 km
# 12    0.7 km
# 13    1.2 km
# 14    0.6 km
# 15    0.6 km
# 16    1.0 km
# 17    0.6 km
# 18    0.8 km
# 19    0.3 km
# 20    0.7 km
# 21    0.5 km
# 22    1.0 km
# 23    1.0 km
# 24    0.6 km
# 25    1.2 km
# 26    1.0 km
# 27    0.4 km
# 28    1.3 km
# 29    1.2 km
# 30    0.9 km
# 31    1.1 km
# 32    1.0 km
# 33    0.4 km
# 34    0.3 km
# 35    0.4 km
# 36    1.4 km
# 37    0.8 km
# 38    1.0 km
# 39    0.7 km
# Name: Distance, dtype: object

# %%
len("Francesco's Pizzeria & Trattoria")
# Out:
# 32
