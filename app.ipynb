# %%
# %load_ext autoreload
# %autoreload 2

from pizza import *

# %%
location = (40.6915812,-73.9954095)
keyword = 'pizza'
ltype = 'establishment'
rankby = 'distance'

print("Searching Google Maps")
gmaps_df = gmaps_get_df(location, keyword)
print("%d results" % len(gmaps_df))

print("Searching Yelp")
yelp_df = yelp_get_df(location, keyword)
print("%d results" % len(yelp_df))

print("Searching Foursquare")
foursquare_df = foursquare_get_df(location, keyword)
print("%d results" % len(foursquare_df))

print("Running dedupe")
dedupe_list = list(filter(lambda df: df is not None, [gmaps_df, yelp_df, foursquare_df]))
print(len(gmaps_df), len(yelp_df), len(foursquare_df))
print("Deduping %d dataframes" % (len(list(dedupe_list))))
dedupe(dedupe_list, (40.6915812,-73.9954095))
# Out:
# Searching Google Maps
# 28 results
# Searching Yelp
# 34 results
# Searching Foursquare
# 16 results
# Running dedupe
# 28 34 16
# Deduping 3 dataframes
# > /Users/drucev/projects/maps/Pizza/Pizza/pizza.py(245)dedupe()
# -> venues_df2 = pandas_dedupe.dedupe_dataframe(venues_df, ['category', 'shortname', 'address', ('latlong', 'LatLong')])
# (Pdb) venues_df.columns
# Index(['index', 'name', 'address', 'rating', 'nratings', 'lat', 'lng',
#        'distance', 'category', 'source', 'url', 'latlong', 'shortname'],
#       dtype='object')
# (Pdb) n
# Importing data ...
# Reading from dedupe_dataframe_learned_settings
# Clustering...
# # duplicate sets 45
# > /Users/drucev/projects/maps/Pizza/Pizza/pizza.py(246)dedupe()
# -> venues_df['cluster'] = venues_df2['cluster id']
# (Pdb) c
#     cluster                                         name  \
# 19       19                                       Lucali
# 1         1                                 Dellarocco's
# 0         0                                    Juliana's
# 3         3                           Piz-zetta Pizzeria
# 34       34                           Sottocasa Pizzeria
# 4         4                                     Table 87
# 25       25                         Forcella Fried Pizza
# 24       24                                        Brado
# 22       22                        Fatoosh Pitza & Grill
# 2         2                 The House of Pizza & Calzone
# 5         5                           Front Street Pizza
# 21       21                  Numero 28 Pizzeria & Cucina
# 10       10                             Fascati Pizzeria
# 6         6                           My Little Pizzeria
# 37       37                                        Sam's
# 36       36                                      Fornino
# 35       35                                  La Cigogne
# 38       38                                   Luzzo's BK
# 39       39                                        Brado
# 40       40                                   Claudine's
# 28       28                         Fresh 99 cents pizza
# 26       26                                  Forno Rosso
# 27       27  Fornino At Pier 6-Open for the 2020 season!
# 11       11                                  Layla Jones
# 20       20                             Enoteca on Court
# 23       23                        Brooklyn Pizza Market
# 15       15                                 Norm’s Pizza
# 29       29                           99 Cents Hot Pizza
# 9         9                          Grimaldi's Pizzeria
# 13       13             Francesco's Pizzeria & Trattoria
# 7         7                            Sal's Pizza Store
# 41       41                                    Ignazio's
# 42       42                                 Pronto Pizza
# 43       43                              Metro Star Café
# 16       16                           Antonio's Pizzeria
# 30       30                            Papa John's Pizza
# 31       31                  Crown Fried Chicken & Pizza
# 32       32                             Mario's Pizzeria
# 12       12                                    Monty Q's
# 14       14                                 Pronto Pizza
# 44       44                                 Love & Dough
# 8         8                      99 Cent Fresh Hot Pizza
# 17       17                                     Caruso's
# 33       33                                  Bella Pizza
# 18       18                               Domino's Pizza
#
#                                         address                lat  \
# 19                                 575 Henry St            40.6818
# 1                                  214 Hicks St         40.6950091
# 0                              19 Old Fulton St         40.7027467
# 3                              90 Livingston St         40.6911691
# 34                             298 Atlantic Ave          40.688285
# 4                               87 Atlantic Ave         40.6912825
# 31         -73.9894995  0.944314      0          3.7             23
# 32         -73.9899575  1.001490      0          3.6             63
# 12         -73.9929947  0.356275      0          4.1            423
# 14          -73.992288  0.354367      0          4.0            136
# 44         -73.9874284  1.438774      1          NaN            NaN
# 8    -73.9868856221437  0.724431      1          NaN            NaN
# 17         -73.9908217  0.673052      0          3.7             87
# 33  -73.98598799999999  0.829980      0          3.0             38
# 18  -73.99049649999999  0.665390      0          2.8            235
#
#     gmaps_rating_std yelp_rating yelp_nratings  yelp_rating_std  \
# 19               NaN         4.5          1580         1.337296
# 1           1.079931         4.0           271         0.462910
# 0           1.079931         4.5          2213         1.337296
# 3           1.079931         4.5           289         1.337296
# 34               NaN         4.5           634         1.337296
# 4           0.855945         4.0           273         0.462910
# 25          0.855945         NaN           NaN              NaN
# 24          0.855945         NaN           NaN              NaN
# 22               NaN         4.0            99         0.462910
# 2           1.079931         4.0           145         0.462910
# 5           0.631960         4.0           358         0.462910
# 21               NaN         4.0           119         0.462910
# 10          0.183988         4.0           236         0.462910
# 6           0.631960         3.5           260        -0.411476
# 37               NaN         4.0           224         0.462910
# 36               NaN         4.0           233         0.462910
# 35               NaN         4.0           357         0.462910
# 38               NaN         4.0           182         0.462910
# 39               NaN         4.0           138         0.462910
# 40               NaN         4.0           117         0.462910
# 28          0.407974         NaN           NaN              NaN
# 26          0.407974         NaN           NaN              NaN
# 27          0.407974         NaN           NaN              NaN
# 11          0.183988         4.0           189         0.462910
# 20               NaN         4.0           254         0.462910
# 23               NaN         3.5            95        -0.411476
# 15         -0.263983         4.0            51         0.462910
# 29         -0.039997         NaN           NaN              NaN
# 9           0.183988         3.5          4613        -0.411476
# 13         -0.039997         3.5            82        -0.411476
# 7           0.631960         3.0           122        -1.285861
# 41               NaN         3.5           522        -0.411476
# 42               NaN         3.5            99        -0.411476
# 43               NaN         3.5            27        -0.411476
# 16         -0.487969         3.5            72        -0.411476
# 30         -0.935940         NaN           NaN              NaN
# 31         -0.935940         NaN           NaN              NaN
# 32         -1.159926         NaN           NaN              NaN
# 12         -0.039997         3.0           232        -1.285861
# 14         -0.263983         NaN           NaN              NaN
# 44               NaN         3.0           166        -1.285861
# 8                NaN         3.5            26        -0.411476
# 17         -0.935940         3.0            73        -1.285861
# 33         -2.503840         NaN           NaN              NaN
# 18         -2.951811         1.5            78        -3.909018
#
#    foursquare_rating foursquare_nratings  foursquare_rating_std  nratings  \
# 19               9.3                 839               1.816540         2
# 1                9.0                 244               1.536174         3
# 0                NaN                 NaN                    NaN         2
# 3                NaN                 NaN                    NaN         2
# 34               NaN                 NaN                    NaN         1
# 4                NaN                 NaN                    NaN         2
# 25               NaN                 NaN                    NaN         1
# 24               NaN                 NaN                    NaN         1
# 22               8.1                  63               0.695075         2
# 2                7.2                  48              -0.146024         3
# 5                NaN                 NaN                    NaN         2
# 21               7.8                 117               0.414709         2
# 10               7.8                 109               0.414709         3
# 6                8.1                 163               0.695075         3
# 37               NaN                 NaN                    NaN         1
# 36               NaN                 NaN                    NaN         1
# 35               NaN                 NaN                    NaN         1
# 38               NaN                 NaN                    NaN         1
# 39               NaN                 NaN                    NaN         1
# 40               NaN                 NaN                    NaN         1
# 28               NaN                 NaN                    NaN         1
# 26               NaN                 NaN                    NaN         1
# 27               NaN                 NaN                    NaN         1
# 11               7.4                  76               0.040887         3
# 20               7.2                  99              -0.146024         2
# 23               7.9                  54               0.508164         2
# 15               7.2                  37              -0.146024         3
# 29               NaN                 NaN                    NaN         1
# 9                NaN                 NaN                    NaN         2
# 13               NaN                 NaN                    NaN         2
# 7                7.3                 134              -0.052569         3
# 41               NaN                 NaN                    NaN         1
# 42               NaN                 NaN                    NaN         1
# 43               NaN                 NaN                    NaN         1
# 16               NaN                 NaN                    NaN         2
# 30               NaN                 NaN                    NaN         1
# 31               NaN                 NaN                    NaN         1
# 32               NaN                 NaN                    NaN         1
# 12               6.6                 105              -0.706757         3
# 14               5.8                  43              -1.454401         2
# 44               NaN                 NaN                    NaN         1
# 8                5.3                  21              -1.921678         2
# 17               5.7                  55              -1.547856         3
# 33               NaN                 NaN                    NaN         1
# 18               NaN                 NaN                    NaN         2
#
#            w         R  bayes_score
# 19  0.535714  1.576918     0.844778
# 1   0.633803  1.026338     0.650496
# 0   0.535714  1.208613     0.647471
# 3   0.535714  1.208613     0.647471
# 34  0.365854  1.337296     0.489255
# 4   0.535714  0.659428     0.353265
# 25  0.365854  0.855945     0.313151
# 24  0.365854  0.855945     0.313151
# 22  0.535714  0.578993     0.310175
# 2   0.633803  0.465606     0.295102
# 5   0.535714  0.547435     0.293269
# 21  0.535714  0.438809     0.235076
# 10  0.633803  0.353869     0.224283
# 6   0.633803  0.305186     0.193428
# 37  0.365854  0.462910     0.169357
# 36  0.365854  0.462910     0.169357
# 35  0.365854  0.462910     0.169357
# 38  0.365854  0.462910     0.169357
# 39  0.365854  0.462910     0.169357
# 40  0.365854  0.462910     0.169357
# 28  0.365854  0.407974     0.149259
# 26  0.365854  0.407974     0.149259
# 27  0.365854  0.407974     0.149259
# 11  0.633803  0.229262     0.145307
# 20  0.535714  0.158443     0.084880
# 23  0.535714  0.048344     0.025899
# 15  0.633803  0.017634     0.011177
# 29  0.365854 -0.039997    -0.014633
# 9   0.535714 -0.113744    -0.060934
# 13  0.535714 -0.225737    -0.120930
# 7   0.633803 -0.235490    -0.149254
# 41  0.365854 -0.411476    -0.150540
# 42  0.365854 -0.411476    -0.150540
# 43  0.365854 -0.411476    -0.150540
# 16  0.535714 -0.449722    -0.240923
# 30  0.365854 -0.935940    -0.342417
# 31  0.365854 -0.935940    -0.342417
# 32  0.365854 -1.159926    -0.424363
# 12  0.633803 -0.677539    -0.429426
# 14  0.535714 -0.859192    -0.460281
# 44  0.365854 -1.285861    -0.470437
# 8   0.535714 -1.166577    -0.624952
# 17  0.633803 -1.256552    -0.796406
# 33  0.365854 -2.503840    -0.916039
# 18  0.535714 -3.430415    -1.837722

# %%
dedupe_df = dedupe(dedupe_list)
dedupe_df
dedupe_df.to_pickle("pizza_brooklynheights.pkl")

# %%
dedupe_df = pd.read_pickle("pizza_brooklynheights.pkl")
tablecols = ['name', 'address', 'distance', 'gmaps_rating', 'yelp_rating', 'foursquare_rating']
tmpdf = dedupe_df.sort_values('bayes_score', ascending=False).reset_index(drop=True)[tablecols]
tmpdf['rank'] = tmpdf.index + 1
tmpdf['distance'] = tmpdf['distance'].apply(lambda d: "%1.1f km" % (float(d)))
tmpdf = tmpdf[['rank'] + tablecols]
tmpdf.columns=['Rank', 'Name', 'Address', 'Distance', 'Google Maps', 'Yelp', 'Foursquare']
retval = tmpdf.to_json(orient="records")
retval

# %%
tmpdf['Distance'].apply(lambda d: "%1.1f km" % (float(d)))

# %%
len("Francesco's Pizzeria & Trattoria")
